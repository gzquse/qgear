# %% [markdown]
# <a href="https://colab.research.google.com/github/gzquse/GRADIENT_IMAGE/blob/main/Bell_CUDA_Q.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -v --no-cache-dir cuquantum-python
# Out:
# Using pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Collecting cuquantum-python
#   Downloading cuquantum_python-24.3.0.post1.tar.gz (6.4 kB)
#   Running command python setup.py egg_info
#   [cuquantum-python] Trying to detect CUDA version from libraries: ['libnvrtc.so.12', 'libnvrtc.so.11.2', 'libnvrtc.so.11.1', 'libnvrtc.so.11.0']
#   [cuquantum-python] Looking for library: libnvrtc.so.12
#   [cuquantum-python] Detected version: 12020
#   [cuquantum-python] Installing cuquantum-python-cu12...
#   /usr/local/lib/python3.10/dist-packages/setuptools/__init__.py:84: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#   !!
#
#           ********************************************************************************
#           Requirements should be satisfied by a PEP 517 installer.
#           If you are using pip, you can try `pip install --use-pep517`.
#           ********************************************************************************
#
#   !!
#     dist.fetch_build_eggs(dist.setup_requires)
#   /usr/local/lib/python3.10/dist-packages/setuptools/dist.py:519: InformationOnly: Normalizing '24.03.0.post1' to '24.3.0.post1'
#     self.metadata.version = self._normalize_version(
#   running egg_info
#   creating /tmp/pip-pip-egg-info-t51amzrf/cuquantum_python.egg-info
#   writing /tmp/pip-pip-egg-info-t51amzrf/cuquantum_python.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-t51amzrf/cuquantum_python.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-pip-egg-info-t51amzrf/cuquantum_python.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-t51amzrf/cuquantum_python.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-t51amzrf/cuquantum_python.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-pip-egg-info-t51amzrf/cuquantum_python.egg-info/SOURCES.txt'
#   adding license file 'LICENSE'
#   writing manifest file '/tmp/pip-pip-egg-info-t51amzrf/cuquantum_python.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# Collecting cuquantum-python-cu12==24.03.0.post1 (from cuquantum-python)
#   Downloading cuquantum_python_cu12-24.3.0.post1-cp310-cp310-manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy~=1.21 in /usr/local/lib/python3.10/dist-packages (from cuquantum-python-cu12==24.03.0.post1->cuquantum-python) (1.25.2)
# Collecting custatevec-cu12~=1.6 (from cuquantum-python-cu12==24.03.0.post1->cuquantum-python)
#   Downloading custatevec_cu12-1.6.0.post1-py3-none-manylinux2014_x86_64.whl (38.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.7/38.7 MB 229.4 MB/s eta 0:00:00
# Collecting cutensornet-cu12~=2.4 (from cuquantum-python-cu12==24.03.0.post1->cuquantum-python)
#   Downloading cutensornet_cu12-2.4.0.post1-py3-none-manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 293.4 MB/s eta 0:00:00
# Collecting cupy-cuda12x>=13.0 (from cuquantum-python-cu12==24.03.0.post1->cuquantum-python)
#   Downloading cupy_cuda12x-13.1.0-cp310-cp310-manylinux2014_x86_64.whl (89.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.5/89.5 MB 175.8 MB/s eta 0:00:00
# Requirement already satisfied: fastrlock>=0.5 in /usr/local/lib/python3.10/dist-packages (from cupy-cuda12x>=13.0->cuquantum-python-cu12==24.03.0.post1->cuquantum-python) (0.8.2)
# Collecting cutensor-cu12<3,>=2.0.1 (from cutensornet-cu12~=2.4->cuquantum-python-cu12==24.03.0.post1->cuquantum-python)
#   Downloading cutensor_cu12-2.0.1-py3-none-manylinux2014_x86_64.whl (152.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.0/152.0 MB 215.2 MB/s eta 0:00:00
# Building wheels for collected packages: cuquantum-python
#   Running command python setup.py bdist_wheel
#   [cuquantum-python] Trying to detect CUDA version from libraries: ['libnvrtc.so.12', 'libnvrtc.so.11.2', 'libnvrtc.so.11.1', 'libnvrtc.so.11.0']
#   [cuquantum-python] Looking for library: libnvrtc.so.12
#   [cuquantum-python] Detected version: 12020
#   [cuquantum-python] Installing cuquantum-python-cu12...
#   /usr/local/lib/python3.10/dist-packages/setuptools/__init__.py:84: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#   !!
#
#           ********************************************************************************
#           Requirements should be satisfied by a PEP 517 installer.
#           If you are using pip, you can try `pip install --use-pep517`.
#           ********************************************************************************
#
#   !!
#     dist.fetch_build_eggs(dist.setup_requires)
#   /usr/local/lib/python3.10/dist-packages/setuptools/dist.py:519: InformationOnly: Normalizing '24.03.0.post1' to '24.3.0.post1'
#     self.metadata.version = self._normalize_version(
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib
#   copying cuda_autodetect.py -> build/lib
#   running egg_info
#   writing cuquantum_python.egg-info/PKG-INFO
#   writing dependency_links to cuquantum_python.egg-info/dependency_links.txt
#   writing requirements to cuquantum_python.egg-info/requires.txt
#   writing top-level names to cuquantum_python.egg-info/top_level.txt
#   reading manifest file 'cuquantum_python.egg-info/SOURCES.txt'
#   adding license file 'LICENSE'
#   writing manifest file 'cuquantum_python.egg-info/SOURCES.txt'
#   /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
#   !!
#
#           ********************************************************************************
#           Please avoid running ``setup.py`` directly.
#           Instead, use pypa/build, pypa/installer, pypa/build or
#           other standards-based tools.
#
#           See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#           ********************************************************************************
#
#   !!
#     self.initialize_options()
#   installing to build/bdist.linux-x86_64/wheel
#   running install
#   running install_lib
#   creating build/bdist.linux-x86_64
#   creating build/bdist.linux-x86_64/wheel
#   copying build/lib/cuda_autodetect.py -> build/bdist.linux-x86_64/wheel
#   running install_egg_info
#   Copying cuquantum_python.egg-info to build/bdist.linux-x86_64/wheel/cuquantum_python-24.3.0.post1-py3.10.egg-info
#   running install_scripts
#   creating build/bdist.linux-x86_64/wheel/cuquantum_python-24.3.0.post1.dist-info/WHEEL
#   creating '/tmp/pip-wheel-9leek37i/cuquantum_python-24.3.0.post1-0_cu12-py3-none-any.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
#   adding 'cuda_autodetect.py'
#   adding 'cuquantum_python-24.3.0.post1.dist-info/LICENSE'
#   adding 'cuquantum_python-24.3.0.post1.dist-info/METADATA'
#   adding 'cuquantum_python-24.3.0.post1.dist-info/WHEEL'
#   adding 'cuquantum_python-24.3.0.post1.dist-info/top_level.txt'
#   adding 'cuquantum_python-24.3.0.post1.dist-info/RECORD'
#   removing build/bdist.linux-x86_64/wheel
#   Building wheel for cuquantum-python (setup.py) ... done
#   Created wheel for cuquantum-python: filename=cuquantum_python-24.3.0.post1-0_cu12-py3-none-any.whl size=6498 sha256=5a03cfff10f9a0654c242d5da9193a373da05bb38902259189d58bc63a4eda30
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dccije63/wheels/20/36/62/23a7b28a32327f2a91ae95e920055d786282da97679e8f6c07
# Successfully built cuquantum-python
# Installing collected packages: cutensor-cu12, custatevec-cu12, cutensornet-cu12, cupy-cuda12x, cuquantum-python-cu12, cuquantum-python
#   Attempting uninstall: cupy-cuda12x
#     Found existing installation: cupy-cuda12x 12.2.0
#     Uninstalling cupy-cuda12x-12.2.0:
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/cupy/
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/cupy_backends/
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/cupy_cuda12x-12.2.0.dist-info/
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/cupyx/
#       Successfully uninstalled cupy-cuda12x-12.2.0
# Successfully installed cupy-cuda12x-13.1.0 cuquantum-python-24.3.0.post1 cuquantum-python-cu12-24.3.0.post1 custatevec-cu12-1.6.0.post1 cutensor-cu12-2.0.1 cutensornet-cu12-2.4.0.post1

# %%
# !pip install -v --no-cache-dir qiskit-aer-gpu
# Out:
# Using pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Collecting qiskit-aer-gpu
#   Downloading qiskit_aer_gpu-0.14.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.8/18.8 MB 44.0 MB/s eta 0:00:00
# Collecting qiskit>=0.45.2 (from qiskit-aer-gpu)
#   Downloading qiskit-1.1.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 139.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.3 in /usr/local/lib/python3.10/dist-packages (from qiskit-aer-gpu) (1.25.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from qiskit-aer-gpu) (1.11.4)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.10/dist-packages (from qiskit-aer-gpu) (5.9.5)
# Collecting nvidia-cuda-runtime-cu12>=12.1.105 (from qiskit-aer-gpu)
#   Downloading nvidia_cuda_runtime_cu12-12.5.39-py3-none-manylinux2014_x86_64.whl (895 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 895.1/895.1 kB 347.4 MB/s eta 0:00:00
# Collecting nvidia-nvjitlink-cu12 (from qiskit-aer-gpu)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 215.0 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12>=12.1.3.1 (from qiskit-aer-gpu)
#   Downloading nvidia_cublas_cu12-12.5.2.13-py3-none-manylinux2014_x86_64.whl (363.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.3/363.3 MB 271.6 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12>=11.4.5.107 (from qiskit-aer-gpu)
#   Downloading nvidia_cusolver_cu12-11.6.2.40-py3-none-manylinux2014_x86_64.whl (130.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.3/130.3 MB 180.6 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12>=12.1.0.106 (from qiskit-aer-gpu)
#   Downloading nvidia_cusparse_cu12-12.4.1.24-py3-none-manylinux2014_x86_64.whl (209.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.2/209.2 MB 155.9 MB/s eta 0:00:00
# Collecting cuquantum-cu12>=23.3.0 (from qiskit-aer-gpu)
#   Downloading cuquantum_cu12-24.3.0.post1-py3-none-manylinux2014_x86_64.whl (7.5 kB)
# Requirement already satisfied: custatevec-cu12==1.6.0.post1 in /usr/local/lib/python3.10/dist-packages (from cuquantum-cu12>=23.3.0->qiskit-aer-gpu) (1.6.0.post1)
# Requirement already satisfied: cutensornet-cu12==2.4.0.post1 in /usr/local/lib/python3.10/dist-packages (from cuquantum-cu12>=23.3.0->qiskit-aer-gpu) (2.4.0.post1)
# Requirement already satisfied: cutensor-cu12<3,>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from cutensornet-cu12==2.4.0.post1->cuquantum-cu12>=23.3.0->qiskit-aer-gpu) (2.0.1)
# Collecting rustworkx>=0.14.0 (from qiskit>=0.45.2->qiskit-aer-gpu)
#   Downloading rustworkx-0.14.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 329.1 MB/s eta 0:00:00
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.10/dist-packages (from qiskit>=0.45.2->qiskit-aer-gpu) (1.12.1)
# Collecting dill>=0.3 (from qiskit>=0.45.2->qiskit-aer-gpu)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 206.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from qiskit>=0.45.2->qiskit-aer-gpu) (2.8.2)
# Collecting stevedore>=3.0.0 (from qiskit>=0.45.2->qiskit-aer-gpu)
#   Downloading stevedore-5.2.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 264.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from qiskit>=0.45.2->qiskit-aer-gpu) (4.12.1)
# Collecting symengine>=0.11 (from qiskit>=0.45.2->qiskit-aer-gpu)
#   Downloading symengine-0.11.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (39.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.4/39.4 MB 288.4 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.0->qiskit>=0.45.2->qiskit-aer-gpu) (1.16.0)
# Collecting pbr!=2.1.0,>=2.0.0 (from stevedore>=3.0.0->qiskit>=0.45.2->qiskit-aer-gpu)
#   Downloading pbr-6.0.0-py2.py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.5/107.5 kB 298.9 MB/s eta 0:00:00
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.3->qiskit>=0.45.2->qiskit-aer-gpu) (1.3.0)
# Installing collected packages: symengine, rustworkx, pbr, nvidia-nvjitlink-cu12, nvidia-cuda-runtime-cu12, nvidia-cublas-cu12, dill, stevedore, nvidia-cusparse-cu12, cuquantum-cu12, qiskit, nvidia-cusolver-cu12, qiskit-aer-gpu
#   changing mode of /usr/local/bin/pbr to 755
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.3.0+cu121 requires nvidia-cuda-cupti-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-cuda-nvrtc-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-cudnn-cu12==8.9.2.26; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-cufft-cu12==11.0.2.54; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-curand-cu12==10.3.2.106; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-nccl-cu12==2.20.5; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-nvtx-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-cublas-cu12==12.1.3.1; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.2.13 which is incompatible.
# torch 2.3.0+cu121 requires nvidia-cuda-runtime-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.39 which is incompatible.
# torch 2.3.0+cu121 requires nvidia-cusolver-cu12==11.4.5.107; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.2.40 which is incompatible.
# torch 2.3.0+cu121 requires nvidia-cusparse-cu12==12.1.0.106; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.4.1.24 which is incompatible.
# Successfully installed cuquantum-cu12-24.3.0.post1 dill-0.3.8 nvidia-cublas-cu12-12.5.2.13 nvidia-cuda-runtime-cu12-12.5.39 nvidia-cusolver-cu12-11.6.2.40 nvidia-cusparse-cu12-12.4.1.24 nvidia-nvjitlink-cu12-12.5.40 pbr-6.0.0 qiskit-1.1.0 qiskit-aer-gpu-0.14.2 rustworkx-0.14.2 stevedore-5.2.0 symengine-0.11.0

# %%
import numpy as np
import cupy as cp

import cuquantum
from cuquantum import custatevec as cusv


nIndexBits = 3
nSvSize    = (1 << nIndexBits)
nMaxShots  = 5
nShots     = 5

bitStringLen  = 2;
bitOrdering   = np.asarray([0, 1], dtype=np.int32)

bitStrings = np.empty((nShots,), dtype=np.int64)
bitStrings_expected = np.asarray([0b00, 0b01, 0b10, 0b11, 0b11], dtype=np.int64)

h_sv          = np.asarray([0.0+0.0j, 0.0+0.1j, 0.1+0.1j, 0.1+0.2j,
                            0.2+0.2j, 0.3+0.3j, 0.3+0.4j, 0.4+0.5j], dtype=np.complex64)

d_sv = cp.asarray(h_sv)

# In real appliction, random numbers in range [0, 1) will be used.
randnums      = np.asarray([0.1, 0.8, 0.4, 0.6, 0.2], dtype=np.float64)

########################################################################

# cuStateVec handle initialization
handle = cusv.create()

# create sampler and check the size of external workspace
sampler, extraWorkspaceSizeInBytes = cusv.sampler_create(
    handle, d_sv.data.ptr, cuquantum.cudaDataType.CUDA_C_32F, nIndexBits, nMaxShots)

# allocate external workspace
extraWorkspace = cp.cuda.alloc(extraWorkspaceSizeInBytes)

# sample preprocess
cusv.sampler_preprocess(
    handle, sampler, extraWorkspace.ptr, extraWorkspaceSizeInBytes)

# sample bit strings
cusv.sampler_sample(
    handle, sampler, bitStrings.ctypes.data, bitOrdering.ctypes.data, bitStringLen,
    randnums.ctypes.data, nShots, cusv.SamplerOutput.ASCENDING_ORDER)

# destroy sampler
cusv.sampler_destroy(sampler)

# destroy handle
cusv.destroy(handle)

if not np.allclose(bitStrings, bitStrings_expected):
    raise ValueError("results mismatch")
print("test passed")
# Out:
# test passed
